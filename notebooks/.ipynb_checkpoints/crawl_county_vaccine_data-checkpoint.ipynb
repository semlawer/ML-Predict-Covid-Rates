# %% [markdown]
# The goal of this notebook is to build a webscraper that, given a url, downloads all necessary csv files (containing county vaccination data).

# %%
import pandas as pd

# %% [markdown]
# Illinois
# Missouri
# Ohio

# %% [markdown]
# ----

# %% [markdown]
# Illinois

# %%
il_counties = ["Adams",
"Alexander",
"Bond",
"Boone",
"Brown",
"Bureau",
"Calhoun",
"Carroll",
"Cass",
"Champaign",
"Christian",
"Clark",
"Clay",
"Clinton",
"Coles",
"Cook",
"Crawford",
"Cumberland",
"De+Witt",
"DeKalb",
"Douglas",
"DuPage",
"Edgar",
"Edwards",
"Effingham",
"Fayette",
"Ford",
"Franklin",
"Fulton",
"Gallatin",
"Greene",
"Grundy",
"Hamilton",
"Hancock",
"Hardin",
"Henderson",
"Henry",
"Iroquois",
"Jackson",
"Jasper",
"Jefferson",
"Jersey",
"Jo+Daviess",
"Johnson",
"Kane",
"Kankakee",
"Kendall",
"Knox",
"Lake",
"LaSalle",
"Lawrence",
"Lee",
"Livingston",
"Logan",
"Macon",
"Macoupin",
"Madison",
"Marion",
"Marshall",
"Mason",
"Massac",
"McDonough",
"McHenry",
"McLean",
"Menard",
"Mercer",
"Monroe",
"Montgomery",
"Morgan",
"Moultrie",
"Ogle",
"Peoria",
"Perry",
"Piatt",
"Pike",
"Pope",
"Pulaski",
"Putnam",
"Randolph",
"Richland",
"Rock+Island",
"Saline",
"Sangamon",
"Schuyler",
"Scott",
"Shelby",
"St.+Clair",
"Stark",
"Stephenson",
"Tazewell",
"Union",
"Vermilion",
"Wabash",
"Warren",
"Washington",
"Wayne",
"White",
"Whiteside",
"Will",
"Williamson",
"Winnebago",
"Woodford",
"Unknown"]

# %%
import requests

# %%
len(il_counties)
# Out:
# 103

# %%
url = "https://idph.illinois.gov/DPHPublicInformation/api/COVIDExport/GetVaccineAdministration?countyname="

# %%
import io

# %%
il_dfs = []

# %%
import urllib.request, json

# %%
r = requests.get(url+"Adams")

# %%
dictr = r.json()

# %%
dictr
# Out:
# [{'CountyName': 'Adams',
#   'AdministeredCount': 5,
#   'AdministeredCountChange': 5,
#   'AdministeredCountRollAvg': 1.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-17T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 9,
#   'AdministeredCountChange': 4,
#   'AdministeredCountRollAvg': 1.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-18T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 9,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 1.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-19T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 9,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 1.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-20T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 9,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 1.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-21T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 9,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 1.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-22T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 545,
#   'AdministeredCountChange': 536,
#   'AdministeredCountRollAvg': 78.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-23T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 789,
#   'AdministeredCountChange': 244,
#   'AdministeredCountRollAvg': 112.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-24T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 789,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 111.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-25T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 789,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 111.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-26T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 789,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 111.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-27T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 957,
#   'AdministeredCountChange': 168,
#   'AdministeredCountRollAvg': 135.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-28T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 1186,
#   'AdministeredCountChange': 229,
#   'AdministeredCountRollAvg': 168.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-29T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 1496,
#   'AdministeredCountChange': 310,
#   'AdministeredCountRollAvg': 136.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-30T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 1572,
#   'AdministeredCountChange': 76,
#   'AdministeredCountRollAvg': 112.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2020-12-31T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 1572,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 112.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2021-01-01T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 1572,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 112.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2021-01-02T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 1572,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 112.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2021-01-03T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 1685,
#   'AdministeredCountChange': 113,
#   'AdministeredCountRollAvg': 104.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2021-01-04T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 1822,
#   'AdministeredCountChange': 137,
#   'AdministeredCountRollAvg': 91.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2021-01-05T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 2106,
#   'AdministeredCountChange': 284,
#   'AdministeredCountRollAvg': 87.0,
#   'PersonsFullyVaccinated': 0,
#   'Report_Date': '2021-01-06T00:00:00',
#   'PctVaccinatedPopulation': 0.0},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 2312,
#   'AdministeredCountChange': 206,
#   'AdministeredCountRollAvg': 106.0,
#   'PersonsFullyVaccinated': 2,
#   'Report_Date': '2021-01-07T00:00:00',
#   'PctVaccinatedPopulation': 3.0445570930568875e-05},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 2480,
#   'AdministeredCountChange': 168,
#   'AdministeredCountRollAvg': 130.0,
#   'PersonsFullyVaccinated': 6,
#   'Report_Date': '2021-01-08T00:00:00',
#   'PctVaccinatedPopulation': 9.133671279170662e-05},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 2480,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 130.0,
#   'PersonsFullyVaccinated': 6,
#   'Report_Date': '2021-01-09T00:00:00',
#   'PctVaccinatedPopulation': 9.133671279170662e-05},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 2480,
#   'AdministeredCountChange': 0,
#   'AdministeredCountRollAvg': 130.0,
#   'PersonsFullyVaccinated': 6,
#   'Report_Date': '2021-01-10T00:00:00',
#   'PctVaccinatedPopulation': 9.133671279170662e-05},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 2517,
#   'AdministeredCountChange': 37,
#   'AdministeredCountRollAvg': 119.0,
#   'PersonsFullyVaccinated': 6,
#   'Report_Date': '2021-01-11T00:00:00',
#   'PctVaccinatedPopulation': 9.133671279170662e-05},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 2633,
#   'AdministeredCountChange': 116,
#   'AdministeredCountRollAvg': 116.0,
#   'PersonsFullyVaccinated': 8,
#   'Report_Date': '2021-01-12T00:00:00',
#   'PctVaccinatedPopulation': 0.0001217822837222755},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 3003,
#   'AdministeredCountChange': 370,
#   'AdministeredCountRollAvg': 128.0,
#   'PersonsFullyVaccinated': 314,
#   'Report_Date': '2021-01-13T00:00:00',
#   'PctVaccinatedPopulation': 0.004779954636099313},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 3346,
#   'AdministeredCountChange': 343,
#   'AdministeredCountRollAvg': 148.0,
#   'PersonsFullyVaccinated': 566,
#   'Report_Date': '2021-01-14T00:00:00',
#   'PctVaccinatedPopulation': 0.008616096573350992},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 3871,
#   'AdministeredCountChange': 525,
#   'AdministeredCountRollAvg': 199.0,
#   'PersonsFullyVaccinated': 675,
#   'Report_Date': '2021-01-15T00:00:00',
#   'PctVaccinatedPopulation': 0.010275380189066995},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 3970,
#   'AdministeredCountChange': 99,
#   'AdministeredCountRollAvg': 213.0,
#   'PersonsFullyVaccinated': 704,
#   'Report_Date': '2021-01-16T00:00:00',
#   'PctVaccinatedPopulation': 0.010716840967560244},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 3972,
#   'AdministeredCountChange': 2,
#   'AdministeredCountRollAvg': 213.0,
#   'PersonsFullyVaccinated': 704,
#   'Report_Date': '2021-01-17T00:00:00',
#   'PctVaccinatedPopulation': 0.010716840967560244},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 4878,
#   'AdministeredCountChange': 906,
#   'AdministeredCountRollAvg': 337.0,
#   'PersonsFullyVaccinated': 855,
#   'Report_Date': '2021-01-18T00:00:00',
#   'PctVaccinatedPopulation': 0.013015481572818195},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 6240,
#   'AdministeredCountChange': 1362,
#   'AdministeredCountRollAvg': 515.0,
#   'PersonsFullyVaccinated': 884,
#   'Report_Date': '2021-01-19T00:00:00',
#   'PctVaccinatedPopulation': 0.013456942351311443},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 7419,
#   'AdministeredCountChange': 1179,
#   'AdministeredCountRollAvg': 631.0,
#   'PersonsFullyVaccinated': 886,
#   'Report_Date': '2021-01-20T00:00:00',
#   'PctVaccinatedPopulation': 0.013487387922242012},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 8591,
#   'AdministeredCountChange': 1172,
#   'AdministeredCountRollAvg': 749.0,
#   'PersonsFullyVaccinated': 887,
#   'Report_Date': '2021-01-21T00:00:00',
#   'PctVaccinatedPopulation': 0.013502610707707296},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 9667,
#   'AdministeredCountChange': 1076,
#   'AdministeredCountRollAvg': 828.0,
#   'PersonsFullyVaccinated': 900,
#   'Report_Date': '2021-01-22T00:00:00',
#   'PctVaccinatedPopulation': 0.013700506918755994},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 9751,
#   'AdministeredCountChange': 84,
#   'AdministeredCountRollAvg': 826.0,
#   'PersonsFullyVaccinated': 900,
#   'Report_Date': '2021-01-23T00:00:00',
#   'PctVaccinatedPopulation': 0.013700506918755994},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 9766,
#   'AdministeredCountChange': 15,
#   'AdministeredCountRollAvg': 828.0,
#   'PersonsFullyVaccinated': 900,
#   'Report_Date': '2021-01-24T00:00:00',
#   'PctVaccinatedPopulation': 0.013700506918755994},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 10488,
#   'AdministeredCountChange': 722,
#   'AdministeredCountRollAvg': 801.0,
#   'PersonsFullyVaccinated': 920,
#   'Report_Date': '2021-01-25T00:00:00',
#   'PctVaccinatedPopulation': 0.014004962628061684},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 11411,
#   'AdministeredCountChange': 923,
#   'AdministeredCountRollAvg': 739.0,
#   'PersonsFullyVaccinated': 1153,
#   'Report_Date': '2021-01-26T00:00:00',
#   'PctVaccinatedPopulation': 0.017551871641472958},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 12424,
#   'AdministeredCountChange': 1013,
#   'AdministeredCountRollAvg': 715.0,
#   'PersonsFullyVaccinated': 1487,
#   'Report_Date': '2021-01-27T00:00:00',
#   'PctVaccinatedPopulation': 0.02263628198687796},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 13261,
#   'AdministeredCountChange': 837,
#   'AdministeredCountRollAvg': 667.0,
#   'PersonsFullyVaccinated': 1833,
#   'Report_Date': '2021-01-28T00:00:00',
#   'PctVaccinatedPopulation': 0.027903365757866373},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 13931,
#   'AdministeredCountChange': 670,
#   'AdministeredCountRollAvg': 609.0,
#   'PersonsFullyVaccinated': 1981,
#   'Report_Date': '2021-01-29T00:00:00',
#   'PctVaccinatedPopulation': 0.03015633800672847},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 13957,
#   'AdministeredCountChange': 26,
#   'AdministeredCountRollAvg': 601.0,
#   'PersonsFullyVaccinated': 1983,
#   'Report_Date': '2021-01-30T00:00:00',
#   'PctVaccinatedPopulation': 0.03018678357765904},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 13965,
#   'AdministeredCountChange': 8,
#   'AdministeredCountRollAvg': 600.0,
#   'PersonsFullyVaccinated': 1983,
#   'Report_Date': '2021-01-31T00:00:00',
#   'PctVaccinatedPopulation': 0.03018678357765904},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 14092,
#   'AdministeredCountChange': 127,
#   'AdministeredCountRollAvg': 515.0,
#   'PersonsFullyVaccinated': 2084,
#   'Report_Date': '2021-02-01T00:00:00',
#   'PctVaccinatedPopulation': 0.03172428490965277},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 15123,
#   'AdministeredCountChange': 1031,
#   'AdministeredCountRollAvg': 530.0,
#   'PersonsFullyVaccinated': 2408,
#   'Report_Date': '2021-02-02T00:00:00',
#   'PctVaccinatedPopulation': 0.03665646740040492},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 16007,
#   'AdministeredCountChange': 884,
#   'AdministeredCountRollAvg': 512.0,
#   'PersonsFullyVaccinated': 2611,
#   'Report_Date': '2021-02-03T00:00:00',
#   'PctVaccinatedPopulation': 0.039746692849857664},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 16681,
#   'AdministeredCountChange': 674,
#   'AdministeredCountRollAvg': 489.0,
#   'PersonsFullyVaccinated': 2697,
#   'Report_Date': '2021-02-04T00:00:00',
#   'PctVaccinatedPopulation': 0.041055852399872125},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 16973,
#   'AdministeredCountChange': 292,
#   'AdministeredCountRollAvg': 435.0,
#   'PersonsFullyVaccinated': 2769,
#   'Report_Date': '2021-02-05T00:00:00',
#   'PctVaccinatedPopulation': 0.042151892953372606},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 17072,
#   'AdministeredCountChange': 99,
#   'AdministeredCountRollAvg': 445.0,
#   'PersonsFullyVaccinated': 2775,
#   'Report_Date': '2021-02-06T00:00:00',
#   'PctVaccinatedPopulation': 0.04224322966616431},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 17104,
#   'AdministeredCountChange': 32,
#   'AdministeredCountRollAvg': 448.0,
#   'PersonsFullyVaccinated': 2776,
#   'Report_Date': '2021-02-07T00:00:00',
#   'PctVaccinatedPopulation': 0.0422584524516296},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 17840,
#   'AdministeredCountChange': 736,
#   'AdministeredCountRollAvg': 535.0,
#   'PersonsFullyVaccinated': 2968,
#   'Report_Date': '2021-02-08T00:00:00',
#   'PctVaccinatedPopulation': 0.04518122726096421},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 18933,
#   'AdministeredCountChange': 1093,
#   'AdministeredCountRollAvg': 544.0,
#   'PersonsFullyVaccinated': 4021,
#   'Report_Date': '2021-02-09T00:00:00',
#   'PctVaccinatedPopulation': 0.061210820355908725},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 20320,
#   'AdministeredCountChange': 1387,
#   'AdministeredCountRollAvg': 616.0,
#   'PersonsFullyVaccinated': 5070,
#   'Report_Date': '2021-02-10T00:00:00',
#   'PctVaccinatedPopulation': 0.0771795223089921},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 21341,
#   'AdministeredCountChange': 1021,
#   'AdministeredCountRollAvg': 666.0,
#   'PersonsFullyVaccinated': 6032,
#   'Report_Date': '2021-02-11T00:00:00',
#   'PctVaccinatedPopulation': 0.09182384192659573},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 22475,
#   'AdministeredCountChange': 1134,
#   'AdministeredCountRollAvg': 786.0,
#   'PersonsFullyVaccinated': 6868,
#   'Report_Date': '2021-02-12T00:00:00',
#   'PctVaccinatedPopulation': 0.10455009057557352},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 22521,
#   'AdministeredCountChange': 46,
#   'AdministeredCountRollAvg': 778.0,
#   'PersonsFullyVaccinated': 6871,
#   'Report_Date': '2021-02-13T00:00:00',
#   'PctVaccinatedPopulation': 0.10459575893196937},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 22564,
#   'AdministeredCountChange': 43,
#   'AdministeredCountRollAvg': 780.0,
#   'PersonsFullyVaccinated': 6872,
#   'Report_Date': '2021-02-14T00:00:00',
#   'PctVaccinatedPopulation': 0.10461098171743466},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 23409,
#   'AdministeredCountChange': 845,
#   'AdministeredCountRollAvg': 796.0,
#   'PersonsFullyVaccinated': 7621,
#   'Report_Date': '2021-02-15T00:00:00',
#   'PctVaccinatedPopulation': 0.1160128480309327},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 24526,
#   'AdministeredCountChange': 1117,
#   'AdministeredCountRollAvg': 799.0,
#   'PersonsFullyVaccinated': 8465,
#   'Report_Date': '2021-02-16T00:00:00',
#   'PctVaccinatedPopulation': 0.12886087896363277},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 25038,
#   'AdministeredCountChange': 512,
#   'AdministeredCountRollAvg': 674.0,
#   'PersonsFullyVaccinated': 8946,
#   'Report_Date': '2021-02-17T00:00:00',
#   'PctVaccinatedPopulation': 0.13618303877243457},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 26010,
#   'AdministeredCountChange': 972,
#   'AdministeredCountRollAvg': 667.0,
#   'PersonsFullyVaccinated': 9460,
#   'Report_Date': '2021-02-18T00:00:00',
#   'PctVaccinatedPopulation': 0.14400755050159078},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 26520,
#   'AdministeredCountChange': 510,
#   'AdministeredCountRollAvg': 578.0,
#   'PersonsFullyVaccinated': 9895,
#   'Report_Date': '2021-02-19T00:00:00',
#   'PctVaccinatedPopulation': 0.1506294621789895},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 26533,
#   'AdministeredCountChange': 13,
#   'AdministeredCountRollAvg': 573.0,
#   'PersonsFullyVaccinated': 9907,
#   'Report_Date': '2021-02-20T00:00:00',
#   'PctVaccinatedPopulation': 0.15081213560457293},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 26567,
#   'AdministeredCountChange': 34,
#   'AdministeredCountRollAvg': 572.0,
#   'PersonsFullyVaccinated': 9941,
#   'Report_Date': '2021-02-21T00:00:00',
#   'PctVaccinatedPopulation': 0.1513297103103926},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 27628,
#   'AdministeredCountChange': 1061,
#   'AdministeredCountRollAvg': 603.0,
#   'PersonsFullyVaccinated': 10712,
#   'Report_Date': '2021-02-22T00:00:00',
#   'PctVaccinatedPopulation': 0.1630664779041269},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 28554,
#   'AdministeredCountChange': 926,
#   'AdministeredCountRollAvg': 575.0,
#   'PersonsFullyVaccinated': 11494,
#   'Report_Date': '2021-02-23T00:00:00',
#   'PctVaccinatedPopulation': 0.17497069613797933},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 29320,
#   'AdministeredCountChange': 766,
#   'AdministeredCountRollAvg': 612.0,
#   'PersonsFullyVaccinated': 12160,
#   'Report_Date': '2021-02-24T00:00:00',
#   'PctVaccinatedPopulation': 0.18510907125785878},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 29953,
#   'AdministeredCountChange': 633,
#   'AdministeredCountRollAvg': 563.0,
#   'PersonsFullyVaccinated': 12753,
#   'Report_Date': '2021-02-25T00:00:00',
#   'PctVaccinatedPopulation': 0.19413618303877245},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 30598,
#   'AdministeredCountChange': 645,
#   'AdministeredCountRollAvg': 583.0,
#   'PersonsFullyVaccinated': 13274,
#   'Report_Date': '2021-02-26T00:00:00',
#   'PctVaccinatedPopulation': 0.20206725426618563},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 31146,
#   'AdministeredCountChange': 548,
#   'AdministeredCountRollAvg': 659.0,
#   'PersonsFullyVaccinated': 13318,
#   'Report_Date': '2021-02-27T00:00:00',
#   'PctVaccinatedPopulation': 0.20273705682665813},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 31207,
#   'AdministeredCountChange': 61,
#   'AdministeredCountRollAvg': 663.0,
#   'PersonsFullyVaccinated': 13355,
#   'Report_Date': '2021-02-28T00:00:00',
#   'PctVaccinatedPopulation': 0.20330029988887366},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 31865,
#   'AdministeredCountChange': 658,
#   'AdministeredCountRollAvg': 605.0,
#   'PersonsFullyVaccinated': 13965,
#   'Report_Date': '2021-03-01T00:00:00',
#   'PctVaccinatedPopulation': 0.21258619902269718},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 32062,
#   'AdministeredCountChange': 197,
#   'AdministeredCountRollAvg': 501.0,
#   'PersonsFullyVaccinated': 14100,
#   'Report_Date': '2021-03-02T00:00:00',
#   'PctVaccinatedPopulation': 0.21464127506051056},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 32298,
#   'AdministeredCountChange': 236,
#   'AdministeredCountRollAvg': 425.0,
#   'PersonsFullyVaccinated': 14296,
#   'Report_Date': '2021-03-03T00:00:00',
#   'PctVaccinatedPopulation': 0.21762494101170632},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 32551,
#   'AdministeredCountChange': 253,
#   'AdministeredCountRollAvg': 371.0,
#   'PersonsFullyVaccinated': 14517,
#   'Report_Date': '2021-03-04T00:00:00',
#   'PctVaccinatedPopulation': 0.22098917659953418},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 33408,
#   'AdministeredCountChange': 857,
#   'AdministeredCountRollAvg': 401.0,
#   'PersonsFullyVaccinated': 15353,
#   'Report_Date': '2021-03-05T00:00:00',
#   'PctVaccinatedPopulation': 0.23371542524851197},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 33556,
#   'AdministeredCountChange': 148,
#   'AdministeredCountRollAvg': 344.0,
#   'PersonsFullyVaccinated': 15451,
#   'Report_Date': '2021-03-06T00:00:00',
#   'PctVaccinatedPopulation': 0.23520725822410984},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 33730,
#   'AdministeredCountChange': 174,
#   'AdministeredCountRollAvg': 360.0,
#   'PersonsFullyVaccinated': 15623,
#   'Report_Date': '2021-03-07T00:00:00',
#   'PctVaccinatedPopulation': 0.23782557732413878},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 34071,
#   'AdministeredCountChange': 341,
#   'AdministeredCountRollAvg': 315.0,
#   'PersonsFullyVaccinated': 15951,
#   'Report_Date': '2021-03-08T00:00:00',
#   'PctVaccinatedPopulation': 0.24281865095675206},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 34523,
#   'AdministeredCountChange': 452,
#   'AdministeredCountRollAvg': 352.0,
#   'PersonsFullyVaccinated': 16367,
#   'Report_Date': '2021-03-09T00:00:00',
#   'PctVaccinatedPopulation': 0.2491513297103104},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 34828,
#   'AdministeredCountChange': 305,
#   'AdministeredCountRollAvg': 361.0,
#   'PersonsFullyVaccinated': 16661,
#   'Report_Date': '2021-03-10T00:00:00',
#   'PctVaccinatedPopulation': 0.253626828637104},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 35288,
#   'AdministeredCountChange': 460,
#   'AdministeredCountRollAvg': 391.0,
#   'PersonsFullyVaccinated': 17112,
#   'Report_Date': '2021-03-11T00:00:00',
#   'PctVaccinatedPopulation': 0.2604923048819473},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 35663,
#   'AdministeredCountChange': 375,
#   'AdministeredCountRollAvg': 322.0,
#   'PersonsFullyVaccinated': 17457,
#   'Report_Date': '2021-03-12T00:00:00',
#   'PctVaccinatedPopulation': 0.2657441658674704},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 35672,
#   'AdministeredCountChange': 9,
#   'AdministeredCountRollAvg': 302.0,
#   'PersonsFullyVaccinated': 17459,
#   'Report_Date': '2021-03-13T00:00:00',
#   'PctVaccinatedPopulation': 0.265774611438401},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 35691,
#   'AdministeredCountChange': 19,
#   'AdministeredCountRollAvg': 280.0,
#   'PersonsFullyVaccinated': 17469,
#   'Report_Date': '2021-03-14T00:00:00',
#   'PctVaccinatedPopulation': 0.26592683929305383},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 36188,
#   'AdministeredCountChange': 497,
#   'AdministeredCountRollAvg': 302.0,
#   'PersonsFullyVaccinated': 17943,
#   'Report_Date': '2021-03-15T00:00:00',
#   'PctVaccinatedPopulation': 0.2731424396035987},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 36439,
#   'AdministeredCountChange': 251,
#   'AdministeredCountRollAvg': 274.0,
#   'PersonsFullyVaccinated': 18163,
#   'Report_Date': '2021-03-16T00:00:00',
#   'PctVaccinatedPopulation': 0.27649145240596124},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 36649,
#   'AdministeredCountChange': 210,
#   'AdministeredCountRollAvg': 260.0,
#   'PersonsFullyVaccinated': 18341,
#   'Report_Date': '2021-03-17T00:00:00',
#   'PctVaccinatedPopulation': 0.27920110821878186},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 36903,
#   'AdministeredCountChange': 254,
#   'AdministeredCountRollAvg': 231.0,
#   'PersonsFullyVaccinated': 18562,
#   'Report_Date': '2021-03-18T00:00:00',
#   'PctVaccinatedPopulation': 0.28256534380660975},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 37257,
#   'AdministeredCountChange': 354,
#   'AdministeredCountRollAvg': 228.0,
#   'PersonsFullyVaccinated': 18801,
#   'Report_Date': '2021-03-19T00:00:00',
#   'PctVaccinatedPopulation': 0.2862035895328127},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 37807,
#   'AdministeredCountChange': 550,
#   'AdministeredCountRollAvg': 305.0,
#   'PersonsFullyVaccinated': 19340,
#   'Report_Date': '2021-03-20T00:00:00',
#   'PctVaccinatedPopulation': 0.294408670898601},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 37876,
#   'AdministeredCountChange': 69,
#   'AdministeredCountRollAvg': 312.0,
#   'PersonsFullyVaccinated': 19405,
#   'Report_Date': '2021-03-21T00:00:00',
#   'PctVaccinatedPopulation': 0.2953981519538445},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 37895,
#   'AdministeredCountChange': 19,
#   'AdministeredCountRollAvg': 244.0,
#   'PersonsFullyVaccinated': 19415,
#   'Report_Date': '2021-03-22T00:00:00',
#   'PctVaccinatedPopulation': 0.29555037980849735},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 37984,
#   'AdministeredCountChange': 89,
#   'AdministeredCountRollAvg': 221.0,
#   'PersonsFullyVaccinated': 19486,
#   'Report_Date': '2021-03-23T00:00:00',
#   'PctVaccinatedPopulation': 0.29663119757653256},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 38072,
#   'AdministeredCountChange': 88,
#   'AdministeredCountRollAvg': 203.0,
#   'PersonsFullyVaccinated': 19554,
#   'Report_Date': '2021-03-24T00:00:00',
#   'PctVaccinatedPopulation': 0.2976663469881719},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 38382,
#   'AdministeredCountChange': 310,
#   'AdministeredCountRollAvg': 211.0,
#   'PersonsFullyVaccinated': 19848,
#   'Report_Date': '2021-03-25T00:00:00',
#   'PctVaccinatedPopulation': 0.3021418459149655},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 38653,
#   'AdministeredCountChange': 271,
#   'AdministeredCountRollAvg': 199.0,
#   'PersonsFullyVaccinated': 20100,
#   'Report_Date': '2021-03-26T00:00:00',
#   'PctVaccinatedPopulation': 0.3059779878522172},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 38805,
#   'AdministeredCountChange': 152,
#   'AdministeredCountRollAvg': 143.0,
#   'PersonsFullyVaccinated': 20245,
#   'Report_Date': '2021-03-27T00:00:00',
#   'PctVaccinatedPopulation': 0.30818529174468345},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 38972,
#   'AdministeredCountChange': 167,
#   'AdministeredCountRollAvg': 157.0,
#   'PersonsFullyVaccinated': 20409,
#   'Report_Date': '2021-03-28T00:00:00',
#   'PctVaccinatedPopulation': 0.3106818285609901},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 39017,
#   'AdministeredCountChange': 45,
#   'AdministeredCountRollAvg': 160.0,
#   'PersonsFullyVaccinated': 20449,
#   'Report_Date': '2021-03-29T00:00:00',
#   'PctVaccinatedPopulation': 0.3112907399796015},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 39281,
#   'AdministeredCountChange': 264,
#   'AdministeredCountRollAvg': 185.0,
#   'PersonsFullyVaccinated': 20505,
#   'Report_Date': '2021-03-30T00:00:00',
#   'PctVaccinatedPopulation': 0.3121432159656574},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 39487,
#   'AdministeredCountChange': 206,
#   'AdministeredCountRollAvg': 202.0,
#   'PersonsFullyVaccinated': 20571,
#   'Report_Date': '2021-03-31T00:00:00',
#   'PctVaccinatedPopulation': 0.3131479198063662},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 39771,
#   'AdministeredCountChange': 284,
#   'AdministeredCountRollAvg': 198.0,
#   'PersonsFullyVaccinated': 20693,
#   'Report_Date': '2021-04-01T00:00:00',
#   'PctVaccinatedPopulation': 0.3150050996331309},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 39827,
#   'AdministeredCountChange': 56,
#   'AdministeredCountRollAvg': 168.0,
#   'PersonsFullyVaccinated': 20736,
#   'Report_Date': '2021-04-02T00:00:00',
#   'PctVaccinatedPopulation': 0.3156596794081381},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 39854,
#   'AdministeredCountChange': 27,
#   'AdministeredCountRollAvg': 150.0,
#   'PersonsFullyVaccinated': 20751,
#   'Report_Date': '2021-04-03T00:00:00',
#   'PctVaccinatedPopulation': 0.3158880211901174},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 39864,
#   'AdministeredCountChange': 10,
#   'AdministeredCountRollAvg': 127.0,
#   'PersonsFullyVaccinated': 20761,
#   'Report_Date': '2021-04-04T00:00:00',
#   'PctVaccinatedPopulation': 0.31604024904477024},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 39891,
#   'AdministeredCountChange': 27,
#   'AdministeredCountRollAvg': 125.0,
#   'PersonsFullyVaccinated': 20785,
#   'Report_Date': '2021-04-05T00:00:00',
#   'PctVaccinatedPopulation': 0.31640559589593703},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 40453,
#   'AdministeredCountChange': 562,
#   'AdministeredCountRollAvg': 167.0,
#   'PersonsFullyVaccinated': 21345,
#   'Report_Date': '2021-04-06T00:00:00',
#   'PctVaccinatedPopulation': 0.3249303557564963},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 40580,
#   'AdministeredCountChange': 127,
#   'AdministeredCountRollAvg': 156.0,
#   'PersonsFullyVaccinated': 21431,
#   'Report_Date': '2021-04-07T00:00:00',
#   'PctVaccinatedPopulation': 0.3262395153065108},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 40655,
#   'AdministeredCountChange': 75,
#   'AdministeredCountRollAvg': 126.0,
#   'PersonsFullyVaccinated': 21476,
#   'Report_Date': '2021-04-08T00:00:00',
#   'PctVaccinatedPopulation': 0.3269245406524486},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 40851,
#   'AdministeredCountChange': 196,
#   'AdministeredCountRollAvg': 146.0,
#   'PersonsFullyVaccinated': 21653,
#   'Report_Date': '2021-04-09T00:00:00',
#   'PctVaccinatedPopulation': 0.3296189736798039},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 41112,
#   'AdministeredCountChange': 261,
#   'AdministeredCountRollAvg': 180.0,
#   'PersonsFullyVaccinated': 21880,
#   'Report_Date': '2021-04-10T00:00:00',
#   'PctVaccinatedPopulation': 0.3330745459804235},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 41367,
#   'AdministeredCountChange': 255,
#   'AdministeredCountRollAvg': 215.0,
#   'PersonsFullyVaccinated': 22111,
#   'Report_Date': '2021-04-11T00:00:00',
#   'PctVaccinatedPopulation': 0.3365910094229042},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 41394,
#   'AdministeredCountChange': 27,
#   'AdministeredCountRollAvg': 215.0,
#   'PersonsFullyVaccinated': 22133,
#   'Report_Date': '2021-04-12T00:00:00',
#   'PctVaccinatedPopulation': 0.3369259107031405},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 41412,
#   'AdministeredCountChange': 18,
#   'AdministeredCountRollAvg': 137.0,
#   'PersonsFullyVaccinated': 22142,
#   'Report_Date': '2021-04-13T00:00:00',
#   'PctVaccinatedPopulation': 0.337062915772328},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 41545,
#   'AdministeredCountChange': 133,
#   'AdministeredCountRollAvg': 138.0,
#   'PersonsFullyVaccinated': 22160,
#   'Report_Date': '2021-04-14T00:00:00',
#   'PctVaccinatedPopulation': 0.33733692591070313},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 41634,
#   'AdministeredCountChange': 89,
#   'AdministeredCountRollAvg': 140.0,
#   'PersonsFullyVaccinated': 22169,
#   'Report_Date': '2021-04-15T00:00:00',
#   'PctVaccinatedPopulation': 0.3374739309798907},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 41713,
#   'AdministeredCountChange': 79,
#   'AdministeredCountRollAvg': 123.0,
#   'PersonsFullyVaccinated': 22187,
#   'Report_Date': '2021-04-16T00:00:00',
#   'PctVaccinatedPopulation': 0.33774794111826584},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 41987,
#   'AdministeredCountChange': 274,
#   'AdministeredCountRollAvg': 125.0,
#   'PersonsFullyVaccinated': 22199,
#   'Report_Date': '2021-04-17T00:00:00',
#   'PctVaccinatedPopulation': 0.3379306145438492},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 41992,
#   'AdministeredCountChange': 5,
#   'AdministeredCountRollAvg': 89.0,
#   'PersonsFullyVaccinated': 22203,
#   'Report_Date': '2021-04-18T00:00:00',
#   'PctVaccinatedPopulation': 0.33799150568571035},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 42024,
#   'AdministeredCountChange': 32,
#   'AdministeredCountRollAvg': 90.0,
#   'PersonsFullyVaccinated': 22221,
#   'Report_Date': '2021-04-19T00:00:00',
#   'PctVaccinatedPopulation': 0.3382655158240855},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 42255,
#   'AdministeredCountChange': 231,
#   'AdministeredCountRollAvg': 120.0,
#   'PersonsFullyVaccinated': 22415,
#   'Report_Date': '2021-04-20T00:00:00',
#   'PctVaccinatedPopulation': 0.34121873620435067},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 42421,
#   'AdministeredCountChange': 166,
#   'AdministeredCountRollAvg': 125.0,
#   'PersonsFullyVaccinated': 22547,
#   'Report_Date': '2021-04-21T00:00:00',
#   'PctVaccinatedPopulation': 0.3432281438857682},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 42638,
#   'AdministeredCountChange': 217,
#   'AdministeredCountRollAvg': 143.0,
#   'PersonsFullyVaccinated': 22729,
#   'Report_Date': '2021-04-22T00:00:00',
#   'PctVaccinatedPopulation': 0.34599869084045},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 42689,
#   'AdministeredCountChange': 51,
#   'AdministeredCountRollAvg': 139.0,
#   'PersonsFullyVaccinated': 22746,
#   'Report_Date': '2021-04-23T00:00:00',
#   'PctVaccinatedPopulation': 0.34625747819335984},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 42759,
#   'AdministeredCountChange': 70,
#   'AdministeredCountRollAvg': 110.0,
#   'PersonsFullyVaccinated': 22768,
#   'Report_Date': '2021-04-24T00:00:00',
#   'PctVaccinatedPopulation': 0.34659237947359606},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 42766,
#   'AdministeredCountChange': 7,
#   'AdministeredCountRollAvg': 111.0,
#   'PersonsFullyVaccinated': 22771,
#   'Report_Date': '2021-04-25T00:00:00',
#   'PctVaccinatedPopulation': 0.3466380478299919},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 42860,
#   'AdministeredCountChange': 94,
#   'AdministeredCountRollAvg': 119.0,
#   'PersonsFullyVaccinated': 22782,
#   'Report_Date': '2021-04-26T00:00:00',
#   'PctVaccinatedPopulation': 0.34680549847011005},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43093,
#   'AdministeredCountChange': 233,
#   'AdministeredCountRollAvg': 120.0,
#   'PersonsFullyVaccinated': 22923,
#   'Report_Date': '2021-04-27T00:00:00',
#   'PctVaccinatedPopulation': 0.34895191122071517},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43256,
#   'AdministeredCountChange': 163,
#   'AdministeredCountRollAvg': 119.0,
#   'PersonsFullyVaccinated': 22989,
#   'Report_Date': '2021-04-28T00:00:00',
#   'PctVaccinatedPopulation': 0.34995661506142395},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43474,
#   'AdministeredCountChange': 218,
#   'AdministeredCountRollAvg': 119.0,
#   'PersonsFullyVaccinated': 23114,
#   'Report_Date': '2021-04-29T00:00:00',
#   'PctVaccinatedPopulation': 0.3518594632445845},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43505,
#   'AdministeredCountChange': 31,
#   'AdministeredCountRollAvg': 117.0,
#   'PersonsFullyVaccinated': 23131,
#   'Report_Date': '2021-04-30T00:00:00',
#   'PctVaccinatedPopulation': 0.35211825059749435},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43509,
#   'AdministeredCountChange': 4,
#   'AdministeredCountRollAvg': 107.0,
#   'PersonsFullyVaccinated': 23134,
#   'Report_Date': '2021-05-01T00:00:00',
#   'PctVaccinatedPopulation': 0.3521639189538902},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43520,
#   'AdministeredCountChange': 11,
#   'AdministeredCountRollAvg': 108.0,
#   'PersonsFullyVaccinated': 23142,
#   'Report_Date': '2021-05-02T00:00:00',
#   'PctVaccinatedPopulation': 0.35228570123761244},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43565,
#   'AdministeredCountChange': 45,
#   'AdministeredCountRollAvg': 101.0,
#   'PersonsFullyVaccinated': 23179,
#   'Report_Date': '2021-05-03T00:00:00',
#   'PctVaccinatedPopulation': 0.352848944299828},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43642,
#   'AdministeredCountChange': 77,
#   'AdministeredCountRollAvg': 78.0,
#   'PersonsFullyVaccinated': 23217,
#   'Report_Date': '2021-05-04T00:00:00',
#   'PctVaccinatedPopulation': 0.3534274101475088},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43714,
#   'AdministeredCountChange': 72,
#   'AdministeredCountRollAvg': 65.0,
#   'PersonsFullyVaccinated': 23277,
#   'Report_Date': '2021-05-05T00:00:00',
#   'PctVaccinatedPopulation': 0.35434077727542584},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43888,
#   'AdministeredCountChange': 174,
#   'AdministeredCountRollAvg': 59.0,
#   'PersonsFullyVaccinated': 23411,
#   'Report_Date': '2021-05-06T00:00:00',
#   'PctVaccinatedPopulation': 0.35638063052777397},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43975,
#   'AdministeredCountChange': 87,
#   'AdministeredCountRollAvg': 67.0,
#   'PersonsFullyVaccinated': 23492,
#   'Report_Date': '2021-05-07T00:00:00',
#   'PctVaccinatedPopulation': 0.357613676150462},
#  {'CountyName': 'Adams',
#   'AdministeredCount': 43992,
#   'AdministeredCountChange': 17,
#   'AdministeredCountRollAvg': 69.0,
#   'PersonsFullyVaccinated': 23504,
#   'Report_Date': '2021-05-08T00:00:00',
#   'PctVaccinatedPopulation': 0.35779634957604545}]

# %%
df = pd.DataFrame()

# %%
list(dictr[0].keys())
# Out:
# ['CountyName',
#  'AdministeredCount',
#  'AdministeredCountChange',
#  'AdministeredCountRollAvg',
#  'PersonsFullyVaccinated',
#  'Report_Date',
#  'PctVaccinatedPopulation']

# %%
list(dictr[0].values())
# Out:
# ['Adams', 5, 5, 1.0, 0, '2020-12-17T00:00:00', 0.0]

# %%
dictr[0]
# Out:
# {'CountyName': 'Adams',
#  'AdministeredCount': 5,
#  'AdministeredCountChange': 5,
#  'AdministeredCountRollAvg': 1.0,
#  'PersonsFullyVaccinated': 0,
#  'Report_Date': '2020-12-17T00:00:00',
#  'PctVaccinatedPopulation': 0.0}

# %%
il_df = pd.DataFrame()

# %%
for county in il_counties:
    url_county = url+county
    r = requests.get(url+county)
    dictr = r.json()
    for row in dictr:
        il_df = il_df.append(pd.DataFrame(row.values()).transpose().rename(columns={0:'CountyName', 1:'AdministeredCount', 2:'AdministeredCountChange', 3:'AdministeredCountRollAvg', 4:'PersonsFullyVaccinated', 5:'Report_Date', 6:'PctVaccinatedPopulation'}))

# %%
il_df['Report_Date'] = pd.to_datetime(il_df['Report_Date'])

# %%
il_df = il_df.merge(il_fips_county, how='left', left_on='CountyName', right_on='county')

# %%
il_df['fips'] = il_df['fips'].astype(str)

# %%
il_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14093 entries, 0 to 14092
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CountyName                14093 non-null  object
#  1   AdministeredCount         14093 non-null  object
#  2   AdministeredCountChange   14093 non-null  object
#  3   AdministeredCountRollAvg  14093 non-null  object
#  4   PersonsFullyVaccinated    14093 non-null  object
#  5   Report_Date               14093 non-null  datetime64[ns]
#  6   PctVaccinatedPopulation   14093 non-null  object
#  7   fips                      14093 non-null  object
#  8   county                    14093 non-null  object
#  9   state                     14093 non-null  object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 1.2+ MB

# %%
il_df.to_csv("../Data/il_vaccine_clean.csv")

# %%
il_fips_county
# Out:
#       fips      county state
# 0    17001       Adams    IL
# 1    17003   Alexander    IL
# 2    17005        Bond    IL
# 3    17007       Boone    IL
# 4    17009       Brown    IL
# ..     ...         ...   ...
# 97   17195   Whiteside    IL
# 98   17197        Will    IL
# 99   17199  Williamson    IL
# 100  17201   Winnebago    IL
# 101  17203    Woodford    IL
#
# [102 rows x 3 columns]

# %%
for county in il_counties:
    url_county = url+county
    r = requests.get(url_county)
    with open('../Raw Data/vaccines/Illinois/' + county, 'wb') as f:
        f.write(r.content)

# %%
adams = pd.read_csv("../Raw Data/vaccines/Illinois/Adams")

# %%
adams
# Out:
# Empty DataFrame
# Columns: [[{"CountyName":"Adams", AdministeredCount:5, AdministeredCountChange:5, AdministeredCountRollAvg:1.000000, PersonsFullyVaccinated:0, Report_Date:"2020-12-17T00:00:00", PctVaccinatedPopulation:0.0}, {"CountyName":"Adams", AdministeredCount:9, AdministeredCountChange:4, AdministeredCountRollAvg:1.000000.1, PersonsFullyVaccinated:0.1, Report_Date:"2020-12-18T00:00:00", PctVaccinatedPopulation:0.0}.1, {"CountyName":"Adams".1, AdministeredCount:9.1, AdministeredCountChange:0, AdministeredCountRollAvg:1.000000.2, PersonsFullyVaccinated:0.2, Report_Date:"2020-12-19T00:00:00", PctVaccinatedPopulation:0.0}.2, {"CountyName":"Adams".2, AdministeredCount:9.2, AdministeredCountChange:0.1, AdministeredCountRollAvg:1.000000.3, PersonsFullyVaccinated:0.3, Report_Date:"2020-12-20T00:00:00", PctVaccinatedPopulation:0.0}.3, {"CountyName":"Adams".3, AdministeredCount:9.3, AdministeredCountChange:0.2, AdministeredCountRollAvg:1.000000.4, PersonsFullyVaccinated:0.4, Report_Date:"2020-12-21T00:00:00", PctVaccinatedPopulation:0.0}.4, {"CountyName":"Adams".4, AdministeredCount:9.4, AdministeredCountChange:0.3, AdministeredCountRollAvg:1.000000.5, PersonsFullyVaccinated:0.5, Report_Date:"2020-12-22T00:00:00", PctVaccinatedPopulation:0.0}.5, {"CountyName":"Adams".5, AdministeredCount:545, AdministeredCountChange:536, AdministeredCountRollAvg:78.000000, PersonsFullyVaccinated:0.6, Report_Date:"2020-12-23T00:00:00", PctVaccinatedPopulation:0.0}.6, {"CountyName":"Adams".6, AdministeredCount:789, AdministeredCountChange:244, AdministeredCountRollAvg:112.000000, PersonsFullyVaccinated:0.7, Report_Date:"2020-12-24T00:00:00", PctVaccinatedPopulation:0.0}.7, {"CountyName":"Adams".7, AdministeredCount:789.1, AdministeredCountChange:0.4, AdministeredCountRollAvg:111.000000, PersonsFullyVaccinated:0.8, Report_Date:"2020-12-25T00:00:00", PctVaccinatedPopulation:0.0}.8, {"CountyName":"Adams".8, AdministeredCount:789.2, AdministeredCountChange:0.5, AdministeredCountRollAvg:111.000000.1, PersonsFullyVaccinated:0.9, Report_Date:"2020-12-26T00:00:00", PctVaccinatedPopulation:0.0}.9, {"CountyName":"Adams".9, AdministeredCount:789.3, AdministeredCountChange:0.6, AdministeredCountRollAvg:111.000000.2, PersonsFullyVaccinated:0.10, Report_Date:"2020-12-27T00:00:00", PctVaccinatedPopulation:0.0}.10, {"CountyName":"Adams".10, AdministeredCount:957, AdministeredCountChange:168, AdministeredCountRollAvg:135.000000, PersonsFullyVaccinated:0.11, Report_Date:"2020-12-28T00:00:00", PctVaccinatedPopulation:0.0}.11, {"CountyName":"Adams".11, AdministeredCount:1186, AdministeredCountChange:229, AdministeredCountRollAvg:168.000000, PersonsFullyVaccinated:0.12, Report_Date:"2020-12-29T00:00:00", PctVaccinatedPopulation:0.0}.12, {"CountyName":"Adams".12, AdministeredCount:1496, AdministeredCountChange:310, AdministeredCountRollAvg:136.000000, PersonsFullyVaccinated:0.13, Report_Date:"2020-12-30T00:00:00", PctVaccinatedPopulation:0.0}.13, {"CountyName":"Adams".13, AdministeredCount:1572, ...]
# Index: []
#
# [0 rows x 1001 columns]

# %% [markdown]
# ___

# %% [markdown]
# Michigan

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/michelleorden/Desktop/CAPP-30254-Covid-Variants/notebooks'

# %%
url_mi1 = "https://www.michigan.gov/documents/coronavirus/Covid_Coverage_State_Level_Metrics_718470_7.xlsx"

# %%
url_mi2 = "https://www.michigan.gov/documents/coronavirus/Covid_Vaccine_Doses_Administered_718468_7.xlsx"

# %%
r = requests.get(url_mi1)

# %%
with open("../Raw Data/vaccines/Michigan/", 'wb') as f:
    f.write(r.content)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-9-9674071d30f5> in <module>
# ----> 1 with open("../Raw Data/vaccines/Michigan/", 'wb') as f:
#       2     f.write(r.content)
#
# IsADirectoryError: [Errno 21] Is a directory: '../Raw Data/vaccines/Michigan/'

# %%
df_mi1 = pd.read_excel("../../../Downloads/Covid_Coverage_State_Level_Metrics_718470_7.xlsx")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-16-0a00b2a16ab9> in <module>
# ----> 1 df_mi1 = pd.read_excel("../../../Downloads/Covid_Coverage_State_Level_Metrics_718470_7.xlsx")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# PermissionError: [Errno 1] Operation not permitted: '../../../Downloads/Covid_Coverage_State_Level_Metrics_718470_7.xlsx'

# %%
df_mi1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 1 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   IMPORTANT NOTE REGARDING COVERAGE DATA FOR ARAB INDIVIDUALS  13 non-null     object
# dtypes: object(1)
# memory usage: 232.0+ bytes

# %% [markdown]
# ____

# %% [markdown]
# Ohio

# %%
oh_df = pd.read_csv("../Raw_Data/vaccines/Ohio_vaccine_data.csv")

# %%
oh_fips_county
# Out:
#      fips      county state
# 0   39001       Adams    OH
# 1   39003       Allen    OH
# 2   39005     Ashland    OH
# 3   39007   Ashtabula    OH
# 4   39009      Athens    OH
# ..    ...         ...   ...
# 83  39167  Washington    OH
# 84  39169       Wayne    OH
# 85  39171    Williams    OH
# 86  39173        Wood    OH
# 87  39175     Wyandot    OH
#
# [88 rows x 3 columns]

# %%
oh_df['county'] = oh_df['county'].apply(lambda x: x.strip())

# %%
oh_df = oh_df.merge(oh_fips_county, how='left')

# %%
oh_df['state'] = oh_df['state'].fillna('OH')

# %%
oh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11970 entries, 0 to 11969
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   county              11970 non-null  object
#  1   date                11970 non-null  object
#  2   vaccines_started    11970 non-null  int64
#  3   vaccines_completed  11970 non-null  int64
#  4   fips                11704 non-null  object
#  5   state               11970 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 654.6+ KB

# %%
oh_df.to_csv("../Data/oh_vaccine_clean.csv")

# %%
oh_df[oh_df['fips'].isnull()]['county'].unique()
# Out:
# array(['Out of State', 'Unknown'], dtype=object)

# %%
oh_fips_county['county'].unique()
# Out:
# array(['Adams', 'Allen', 'Ashland', 'Ashtabula', 'Athens', 'Auglaize',
#        'Belmont', 'Brown', 'Butler', 'Carroll', 'Champaign', 'Clark',
#        'Clermont', 'Clinton', 'Columbiana', 'Coshocton', 'Crawford',
#        'Cuyahoga', 'Darke', 'Defiance', 'Delaware', 'Erie', 'Fairfield',
#        'Fayette', 'Franklin', 'Fulton', 'Gallia', 'Geauga', 'Greene',
#        'Guernsey', 'Hamilton', 'Hancock', 'Hardin', 'Harrison', 'Henry',
#        'Highland', 'Hocking', 'Holmes', 'Huron', 'Jackson', 'Jefferson',
#        'Knox', 'Lake', 'Lawrence', 'Licking', 'Logan', 'Lorain', 'Lucas',
#        'Madison', 'Mahoning', 'Marion', 'Medina', 'Meigs', 'Mercer',
#        'Miami', 'Monroe', 'Montgomery', 'Morgan', 'Morrow', 'Muskingum',
#        'Noble', 'Ottawa', 'Paulding', 'Perry', 'Pickaway', 'Pike',
#        'Portage', 'Preble', 'Putnam', 'Richland', 'Ross', 'Sandusky',
#        'Scioto', 'Seneca', 'Shelby', 'Stark', 'Summit', 'Trumbull',
#        'Tuscarawas', 'Union', 'Van Wert', 'Vinton', 'Warren',
#        'Washington', 'Wayne', 'Williams', 'Wood', 'Wyandot'], dtype=object)

# %% [markdown]
# ____

# %% [markdown]
# fips

# %%
il_fips = [17001
,17003
,17005
,17007
,17009
,17011
,17013
,17015
,17017
,17019
,17021
,17023
,17025
,17027
,17029
,17031
,17033
,17035
,17037
,17039
,17041
,17043
,17045
,17047
,17049
,17051
,17053
,17055
,17057
,17059
,17061
,17063
,17065
,17067
,17069
,17071
,17073
,17075
,17077
,17079
,17081
,17083
,17085
,17087
,17089
,17091
,17093
,17095
,17097
,17099
,17101
,17103
,17105
,17107
,17109
,17111
,17113
,17115
,17117
,17119
,17121
,17123
,17125
,17127
,17129
,17131
,17133
,17135
,17137
,17139
,17141
,17143
,17145
,17147
,17149
,17151
,17153
,17155
,17157
,17159
,17161
,17163
,17165
,17167
,17169
,17171
,17173
,17175
,17177
,17179
,17181
,17183
,17185
,17187
,17189
,17191
,17193
,17195
,17197
,17199
,17201
,17203]

# %%
il_counties = ["Adams"
,"Alexander"
,"Bond"
,"Boone"
,"Brown"
,"Bureau"
,"Calhoun"
,"Carroll"
,"Cass"
,"Champaign"
,"Christian"
,"Clark"
,"Clay"
,"Clinton"
,"Coles"
,"Cook"
,"Crawford"
,"Cumberland"
,"De Kalb"
,"De Witt"
,"Douglas"
,"Du Page"
,"Edgar"
,"Edwards"
,"Effingham"
,"Fayette"
,"Ford"
,'Franklin'
,"Fulton"
,"Gallatin"
,"Greene"
,"Grundy"
,"Hamilton"
,"Hancock"
,"Hardin"
,"Henderson"
,"Henry"
,"Iroquois"
,"Jackson"
,"Jasper"
,"Jefferson"
,"Jersey"
,"Jo Daviess"
,"Johnson"
,"Kane"
,"Kankakee"
,"Kendall"
,"Knox"
,"Lake"
,"La Salle"
,"Lawrence"
,"Lee"
,"Livingston"
,"Logan"
,"McDonough"
,"McHenry"
,"McLean"
,"Macon"
,"Macoupin"
,"Madison"
,"Marion"
,"Marshall"
,"Mason"
,"Massac"
,"Menard"
,"Mercer"
,"Monroe"
,"Montgomery"
,"Morgan"
,"Moultrie"
,"Ogle"
,"Peoria"
,"Perry"
,"Piatt"
,"Pike"
,"Pope"
,"Pulaski"
,"Putnam"
,"Randolph"
,"Richland"
,"Rock Island"
,"St Clair"
,"Saline"
,"Sangamon"
,"Schuyler"
,"Scott"
,"Shelby"
,"Stark"
,"Stephenson"
,"Tazewell"
,"Union"
,"Vermilion"
,"Wabash"
,"Warren"
,"Washington"
,"Wayne"
,"White"
,"Whiteside"
,"Will"
,"Williamson"
,"Winnebago"
,"Woodford"]

# %%
len(il_fips)
# Out:
# 102

# %%
len(il_counties)
# Out:
# 102

# %%
il_fips_county = pd.DataFrame(il_fips)

# %%
il_fips_county = il_fips_county.rename(columns={0:"fips"})

# %%
il_fips_county["county"] = il_counties

# %%
il_fips_county['state'] = 'IL'

# %%
il_fips_county
# Out:
#       fips      county state
# 0    17001       Adams    IL
# 1    17003   Alexander    IL
# 2    17005        Bond    IL
# 3    17007       Boone    IL
# 4    17009       Brown    IL
# ..     ...         ...   ...
# 97   17195   Whiteside    IL
# 98   17197        Will    IL
# 99   17199  Williamson    IL
# 100  17201   Winnebago    IL
# 101  17203    Woodford    IL
#
# [102 rows x 3 columns]

# %%
oh = [39001,	"Adams",	"OH",
39003,	"Allen",	"OH",
39005,	"Ashland",	"OH",
39007,	"Ashtabula",	"OH",
39009,	"Athens",	"OH",
39011,	"Auglaize",	"OH",
39013,	"Belmont",	"OH",
39015,	"Brown",	"OH",
39017,	"Butler",	"OH",
39019,	"Carroll",	"OH",
39021,	"Champaign",	"OH",
39023,	"Clark",	"OH",
39025,	"Clermont",	"OH",
39027,	"Clinton",	"OH",
39029,	"Columbiana",	"OH",
39031,	"Coshocton",	"OH",
39033,	"Crawford",	"OH",
39035,	"Cuyahoga",	"OH",
39037,	"Darke",	'OH',
39039,	"Defiance",	'OH',
39041,	"Delaware",	'OH',
39043,	"Erie",	'OH',
39045,	"Fairfield",	'OH',
39047,	"Fayette",	'OH',
39049,	"Franklin",	'OH',
39051,	"Fulton",	'OH',
39053,	"Gallia",	'OH',
39055,	"Geauga",	'OH',
39057,	"Greene",	'OH',
39059,	"Guernsey",	'OH',
39061,	"Hamilton",	'OH',
39063,	"Hancock",	'OH',
39065,	"Hardin",	'OH',
39067,	"Harrison",	'OH',
39069,	"Henry",	'OH',
39071,	"Highland",	'OH',
39073,	"Hocking",	'OH',
39075,	"Holmes",	'OH',
39077,	"Huron",	'OH',
39079,	"Jackson",	'OH',
39081,	"Jefferson",	'OH',
39083,	"Knox",	'OH',
39085,	"Lake",	'OH',
39087,	"Lawrence",	'OH',
39089,	"Licking",	'OH',
39091,	"Logan",	'OH',
39093,	"Lorain",	'OH',
39095,	"Lucas",	'OH',
39097,	"Madison",	'OH',
39099,	"Mahoning",	'OH',
39101,	"Marion",	'OH',
39103,	"Medina",	'OH',
39105,	"Meigs",	'OH',
39107,	"Mercer",	'OH',
39109,	"Miami",	'OH',
39111,	"Monroe",	'OH',
39113,	"Montgomery",	'OH',
39115,	"Morgan",	'OH',
39117,	"Morrow",	'OH',
39119,	"Muskingum",	'OH',
39121,	"Noble",	'OH',
39123,	"Ottawa",	'OH',
39125,	"Paulding",	'OH',
39127,	"Perry",	'OH',
39129,	"Pickaway",	'OH',
39131,	"Pike",	'OH',
39133,	"Portage",	'OH',
39135,	"Preble",	'OH',
39137,	"Putnam",	'OH',
39139,	"Richland",	'OH',
39141,	"Ross",	'OH',
39143,	"Sandusky",	'OH',
39145,	"Scioto",	'OH',
39147,	"Seneca",	'OH',
39149,	"Shelby",	'OH',
39151,	"Stark",	'OH',
39153,	"Summit",	'OH',
39155,	"Trumbull",	'OH',
39157,	"Tuscarawas",	'OH',
39159,	"Union",	'OH',
39161,	"Van Wert",	'OH',
39163,	"Vinton",	'OH',
39165,	"Warren",	'OH',
39167,	"Washington",	'OH',
39169,	"Wayne",	'OH',
39171,	"Williams",	'OH',
39173,	"Wood",	'OH',
39175,	"Wyandot",	'OH']

# %%
len(oh)
# Out:
# 264

# %%
import numpy as np

# %%
oh_fips_county = pd.DataFrame(np.reshape(oh, (88, 3))).rename(columns={0:'fips', 1:'county', 2:'state'})

# %%
oh_fips_county
# Out:
#      fips      county state
# 0   39001       Adams    OH
# 1   39003       Allen    OH
# 2   39005     Ashland    OH
# 3   39007   Ashtabula    OH
# 4   39009      Athens    OH
# ..    ...         ...   ...
# 83  39167  Washington    OH
# 84  39169       Wayne    OH
# 85  39171    Williams    OH
# 86  39173        Wood    OH
# 87  39175     Wyandot    OH
#
# [88 rows x 3 columns]

# %%
mo = [29001,	'Adair',	'MO',
29003	,'Andrew',	'MO',
29005	,'Atchison',	'MO',
29007	,'Audrain',	'MO',
29009	,'Barry'	,'MO',
29011	,'Barton'	,'MO',
29013	,'Bates'	,'MO',
29015	,'Benton'	,'MO',
29017	,'Bollinger',	'MO',
29019	,'Boone'	,'MO',
29021	,'Buchanan',	'MO',
29023	,'Butler'	,'MO',
29025	,'Caldwell',	'MO',
29027	,'Callaway',	'MO',
29029	,'Camden'	,'MO',
29031	,'Cape Girardeau',	'MO',
29033	,'Carroll'	,'MO',
29035	,'Carter'	,'MO',
29037	,'Cass'	,'MO',
29039	,'Cedar'	,'MO',
29041	,'Chariton'	,'MO',
29043	,'Christian'	,'MO',
29045	,'Clark'	,'MO',
29047	,'Clay'	,'MO',
29049	,'Clinton',	'MO',
29051	,'Cole'	,'MO',
29053	,'Cooper'	,'MO',
29055	,'Crawford',	'MO',
29057	,'Dade'	,'MO',
29059	,'Dallas'	,'MO',
29061	,'Daviess',	'MO',
29063	,'De Kalb',	'MO',
29065	,'Dent'	,'MO',
29067	,'Douglas',	'MO',
29069	,'Dunklin',	'MO',
29071	,'Franklin',	'MO',
29073	,'Gasconade',	'MO',
29075	,'Gentry'	,'MO',
29077	,'Greene'	,'MO',
29079	,'Grundy'	,'MO',
29081	,'Harrison',	'MO',
29083	,'Henry'	,'MO',
29085	,'Hickory',	'MO',
29087	,'Holt'	,'MO',
29089	,'Howard'	,'MO',
29091	,'Howell'	,'MO',
29093	,'Iron'	,'MO',
29095	,'Jackson',	'MO',
29097	,'Jasper'	,'MO',
29099	,'Jefferson',	'MO',
29101	,'Johnson'	,'MO',
29103	,'Knox'	,'MO',
29105	,'Laclede',	'MO',
29107	,'Lafayette',	'MO',
29109	,'Lawrence',	'MO',
29111	,'Lewis'	,'MO',
29113	,'Lincoln',	'MO',
29115	,'Linn'	,'MO',
29117	,'Livingston',	'MO',
29119	,'McDonald',	'MO',
29121	,'Macon'	,'MO',
29123	,'Madison',	'MO',
29125	,'Maries'	,'MO',
29127	,'Marion'	,'MO',
29129	,'Mercer'	,'MO',
29131	,'Miller'	,'MO',
29133	,'Mississippi',	'MO',
29135	,'Moniteau'	,'MO',
29137	,'Monroe'	,'MO',
29139	,'Montgomery',	'MO',
29141	,'Morgan'	,'MO',
29143	,'New Madrid',	'MO',
29145	,'Newton'	,'MO',
29147	,'Nodaway',	'MO',
29149	,'Oregon'	,'MO',
29151	,'Osage'	,'MO',
29153	,'Ozark'	,'MO',
29155	,'Pemiscot'	,'MO',
29157	,'Perry'	,'MO',
29159	,'Pettis'	,'MO',
29161	,'Phelps'	,'MO',
29163	,'Pike'	,'MO',
29165	,'Platte'	,'MO',
29167	,'Polk'	,'MO',
29169	,'Pulaski',	'MO',
29171	,'Putnam'	,'MO',
29173	,'Ralls'	,'MO',
29175	,'Randolph',	'MO',
29177	,'Ray'	,'MO',
29179	,'Reynolds',	'MO',
29181	,'Ripley'	,'MO',
29183	,'St Charles',	'MO',
29185	,'St Clair',	'MO',
29186	,'Ste. Genevieve',	'MO',
29187	,'St Francois',	'MO',
29189	,'St Louis',	'MO',
29195	,'Saline'	,'MO',
29197	,'Schuyler',	'MO',
29199	,'Scotland',	'MO',
29201	,'Scott'	,'MO',
29203	,'Shannon',	'MO',
29205	,'Shelby'	,'MO',
29207	,'Stoddard',	'MO',
29209	,'Stone'	,'MO',
29211	,'Sullivan',	'MO',
29213	,'Taney'	,'MO',
29215	,'Texas'	,'MO',
29217	,'Vernon'	,'MO',
29219	,'Warren'	,'MO',
29221	,'Washington',	'MO',
29223	,'Wayne'	,'MO',
29225	,'Webster',	'MO',
29227	,'Worth'	,'MO',
29229	,'Wright'	,'MO',
29510	,'St Louis City',	'MO']

# %%
len(mo)
# Out:
# 345

# %%
mo_fips_county = pd.DataFrame(np.reshape(mo, (115, 3))).rename(columns={0:'fips', 1:'county', 2:'state'})

# %%
mo_fips_county
# Out:
#       fips         county state
# 0    29001          Adair    MO
# 1    29003         Andrew    MO
# 2    29005       Atchison    MO
# 3    29007        Audrain    MO
# 4    29009          Barry    MO
# ..     ...            ...   ...
# 110  29223          Wayne    MO
# 111  29225        Webster    MO
# 112  29227          Worth    MO
# 113  29229         Wright    MO
# 114  29510  St Louis City    MO
#
# [115 rows x 3 columns]

# %%
mi = [26001,	'Alcona',	'MI',
26003,	'Alger',	'MI',
26005,	'Allegan',	'MI',
26007,	'Alpena',	'MI',
26009,	'Antrim',	'MI',
26011,	'Arenac',	'MI',
26013,	'Baraga',	'MI',
26015,	'Barry',	'MI',
26017,	'Bay'	,'MI',
26019,	'Benzie'	,'MI',
26021,	'Berrien'	,'MI',
26023,	'Branch'	,'MI',
26025,	'Calhoun'	,'MI',
26027,	'Cass'	,'MI',
26029,	'Charlevoix',	'MI',
26031,	'Cheboygan',	'MI',
26033,	'Chippewa',	'MI',
26035,	'Clare'	,'MI',
26037,	'Clinton'	,'MI',
26039,	'Crawford',	'MI',
26041,	'Delta'	,'MI',
26043,	'Dickinson',	'MI',
26045,	'Eaton'	,'MI',
26047,	'Emmet'	,'MI',
26049,	'Genesee'	,'MI',
26051,	'Gladwin'	,'MI',
26053,	'Gogebic'	,'MI',
26055,	'Grand Traverse',	'MI',
26057,	'Gratiot'	,'MI',
26059,	'Hillsdale',	'MI',
26061,	'Houghton',	'MI',
26063,	'Huron'	,'MI',
26065,	'Ingham'	,'MI',
26067,	'Ionia'	,'MI',
26069,	'Iosco'	,'MI',
26071,	'Iron'	,'MI',
26073,	'Isabella',	'MI',
26075,	'Jackson'	,'MI',
26077,	'Kalamazoo',	'MI',
26079,	'Kalkaska',	'MI',
26081,	'Kent'	,'MI',
26083,	'Keweenaw',	'MI',
26085,	'Lake'	,'MI',
26087,	'Lapeer'	,'MI',
26089,	'Leelanau',	'MI',
26091,	'Lenawee'	,'MI',
26093,	'Livingston',	'MI',
26095,	'Luce'	,'MI',
26097,	'Mackinac',	'MI',
26099,	'Macomb'	,'MI',
26101,	'Manistee',	'MI',
26103,	'Marquette',	'MI',
26105,	'Mason'	,'MI',
26107,	'Mecosta'	,'MI',
26109,	'Menominee',	'MI',
26111,	'Midland'	,'MI',
26113,	'Missaukee',	'MI',
26115,	'Monroe'	,'MI',
26117,	'Montcalm',	'MI',
26119,	'Montmorency',	'MI',
26121,	'Muskegon',	'MI',
26123,	'Newaygo'	,'MI',
26125,	'Oakland'	,'MI',
26127,	'Oceana'	,'MI',
26129,	'Ogemaw'	,'MI',
26131,	'Ontonagon',	'MI',
26133,	'Osceola'	,'MI',
26135,	'Oscoda'	,'MI',
26137,	'Otsego'	,'MI',
26139,	'Ottawa'	,'MI',
26141,	'Presque Isle',	'MI',
26143,	'Roscommon',	'MI',
26145,	'Saginaw'	,'MI',
26147,	'St Clair',	'MI',
26149,	'St Joseph',	'MI',
26151,	'Sanilac'	,'MI',
26153,	'Schoolcraft',	'MI',
26155,	'Shiawassee',	'MI',
26157,	'Tuscola'	,'MI',
26159,	'Van Buren',	'MI',
26161,	'Washtenaw',	'MI',
26163,	'Wayne'	,'MI',
26165,	'Wexford'	,'MI']

# %%
len(mi)
# Out:
# 249

# %%
mi_fips_county = pd.DataFrame(np.reshape(mi, (83, 3))).rename(columns={0:'fips', 1:'county', 2:'state'})

# %%
mi_fips_county
# Out:
#      fips     county state
# 0   26001     Alcona    MI
# 1   26003      Alger    MI
# 2   26005    Allegan    MI
# 3   26007     Alpena    MI
# 4   26009     Antrim    MI
# ..    ...        ...   ...
# 78  26157    Tuscola    MI
# 79  26159  Van Buren    MI
# 80  26161  Washtenaw    MI
# 81  26163      Wayne    MI
# 82  26165    Wexford    MI
#
# [83 rows x 3 columns]
